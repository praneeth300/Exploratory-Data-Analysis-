# %% [markdown]
# ### Project on Employee Attrition

# %% [markdown]
# #### Import the libraries

# %%
import pandas as pd
import numpy as np
pd.pandas.set_option('display.max_columns',None)

# %% [markdown]
# #### Data loading

# %%
hr=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# #### EDA

# %%
print('\nEDA\n')
print('*'*40)
print('\nNumber of Records: ',hr.shape[0])
print('Number of Observations: ',hr.shape[1],'\n')
print('*'*40)
print('\nData types\n')
print(hr.dtypes)
print('*'*40)
print('\nInfo\n')
print(hr.info())
print('*'*40)
print('\nColumns: ',hr.columns)
# Out:
# EDA
#
# ****************************************
#
# Number of Records:  1470
# Number of Observations:  35
#
# ****************************************
#
# Data types
#
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# ...

# %%
hr.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#Plot the correlation of the data with each variable 
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,10))
sns.heatmap(hr.corr(),annot=True,cmap='viridis')
plt.show()

# %% [markdown]
# #### Missing values

# %%
#get the missing values and percentage of the missing data
null_data=pd.DataFrame({'Missing_values':hr.isnull().sum(),'Percentage_of_Null':(hr.isnull().sum()/hr.shape[0])})
null_data
# Out:
#                           Missing_values  Percentage_of_Null
# Age                                    0                 0.0
# Attrition                              0                 0.0
# BusinessTravel                         0                 0.0
# DailyRate                              0                 0.0
# Department                             0                 0.0
# DistanceFromHome                       0                 0.0
# Education                              0                 0.0
# EducationField                         0                 0.0
# EmployeeCount                          0                 0.0
# EmployeeNumber                         0                 0.0
# EnvironmentSatisfaction                0                 0.0
# Gender                                 0                 0.0
# HourlyRate                             0                 0.0
# JobInvolvement                         0                 0.0
# ...

# %% [markdown]
# #### Numerical values

# %%
#Get the numerical data columns dtype='int or float'
num_data=[num for num in hr.columns if hr[num].dtype !='O']
num_df=hr[num_data]
num_df.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# ...

# %%
#Extract the numerical unque_values and dtype
num_unique=pd.DataFrame({'Unique_values':num_df.nunique(),'Dtype':num_df.dtypes})
num_unique
# Out:
#                           Unique_values  Dtype
# Age                                  43  int64
# DailyRate                           886  int64
# DistanceFromHome                     29  int64
# Education                             5  int64
# EmployeeCount                         1  int64
# EmployeeNumber                     1470  int64
# EnvironmentSatisfaction               4  int64
# HourlyRate                           71  int64
# JobInvolvement                        4  int64
# JobLevel                              5  int64
# JobSatisfaction                       4  int64
# MonthlyIncome                      1349  int64
# MonthlyRate                        1427  int64
# NumCompaniesWorked                   10  int64
# PercentSalaryHike                    15  int64
# PerformanceRating                     2  int64
# RelationshipSatisfaction              4  int64
# StandardHours                         1  int64
# StockOptionLevel                      4  int64
# ...

# %% [markdown]
# #### Discreate values

# %%
#Numerical features are of two type 
#1.Discreate features
#2.Countineous features
discreat_data=[d for d in num_data if len(hr[d].unique()) < 25]
dis=hr[discreat_data]
dis.head()
# Out:
#    Education  EmployeeCount  EnvironmentSatisfaction  JobInvolvement  \
# 0          2              1                        2               3
# 1          1              1                        3               2
# 2          2              1                        4               2
# 3          4              1                        4               3
# 4          1              1                        1               3
#
#    JobLevel  JobSatisfaction  NumCompaniesWorked  PercentSalaryHike  \
# 0         2                4                   8                 11
# 1         2                2                   1                 23
# 2         1                3                   6                 15
# 3         1                3                   1                 11
# 4         1                2                   9                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# ...

# %%
def plo_ba(variable,data):
    plt.style.use('tableau-colorblind10')
    plt.figure(figsize=(10,6))
    ax=sns.countplot(x=variable,data=data,palette='BuPu')
    ax.set_title(variable)
    plt.show()

# %%
for fd in dis.columns:
    plo_ba(fd,dis)

# %% [markdown]
# #### Countinuoes features

# %%
#2.Countineous features
cont_data=[c for c in num_data if c not in discreat_data]
hr[cont_data].head()
# Out:
#    Age  DailyRate  DistanceFromHome  EmployeeNumber  HourlyRate  \
# 0   41       1102                 1               1          94
# 1   49        279                 8               2          61
# 2   37       1373                 2               4          92
# 3   33       1392                 3               5          56
# 4   27        591                 2               7          40
#
#    MonthlyIncome  MonthlyRate  TotalWorkingYears  YearsAtCompany
# 0           5993        19479                  8               6
# 1           5130        24907                 10              10
# 2           2090         2396                  7               0
# 3           2909        23159                  8               8
# 4           3468        16632                  6               2

# %% [markdown]
# #### Categorical values

# %%
#Extract the Categorical data column dtype='Object or bool'
cat_data=[cat for cat in hr.columns if hr[cat].dtype == 'O']
cat_df=hr[cat_data]
cat_df.head()
# Out:
#   Attrition     BusinessTravel              Department EducationField  Gender  \
# 0       Yes      Travel_Rarely                   Sales  Life Sciences  Female
# 1        No  Travel_Frequently  Research & Development  Life Sciences    Male
# 2       Yes      Travel_Rarely  Research & Development          Other    Male
# 3        No  Travel_Frequently  Research & Development  Life Sciences  Female
# 4        No      Travel_Rarely  Research & Development        Medical    Male
#
#                  JobRole MaritalStatus Over18 OverTime
# 0        Sales Executive        Single      Y      Yes
# 1     Research Scientist       Married      Y       No
# 2  Laboratory Technician        Single      Y      Yes
# 3     Research Scientist       Married      Y      Yes
# 4  Laboratory Technician       Married      Y       No

# %%
#Categorical unique values 
cat_unique=pd.DataFrame({'Unique_values':cat_df.nunique(),'Dtypes':cat_df.dtypes})
cat_unique
# Out:
#                 Unique_values  Dtypes
# Attrition                   2  object
# BusinessTravel              3  object
# Department                  3  object
# EducationField              6  object
# Gender                      2  object
# JobRole                     9  object
# MaritalStatus               3  object
# Over18                      1  object
# OverTime                    2  object

# %%
def plot_cat(data,variable):
    plt.figure(figsize=(12,7))
    plt.style.use('seaborn')
    ax=sns.countplot(variable,data=data,palette='dark')
    ax.set_title(variable,fontsize=19)
    ax.set_xlabel(variable,fontsize=17)
    ax.set_ylabel('Count',fontsize=17)
    plt.xticks(rotation=90)
    plt.show()

# %%
for v in cat_df.columns: #Visualize the categorical column with the help of countplot
    plot_cat(hr,v)

# %%
#Plot the distribution of the numerical data 
num_df.hist(bins=30,figsize=(15,15))
plt.show()

# %%
sns.catplot(x='Attrition',y='MonthlyIncome',data=hr,kind='box')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.lmplot(x='TotalWorkingYears',y='MonthlyIncome',col='Attrition',data=hr,palette='dark',markers='*')
plt.show()

# %%
def plot_df2(data,variable,gh='MonthlyIncome',c='Attrition'):
    plt.style.use('seaborn-whitegrid')
    plt.figure(figsize=(10,8))
    ax=sns.catplot(x=variable,y=gh,data=data,kind='bar',col=c,palette='plasma')
    ax.set_xticklabels(rotation=90)
    plt.show()

# %%
for vj in cat_df.columns:
    plot_df2(hr,vj)

# %%
def plot_df3(data,variable,gh='MonthlyRate',c='Attrition'):
    plt.style.use('seaborn')
    plt.figure(figsize=(10,8))
    ax=sns.catplot(x=variable,y=gh,data=data,kind='bar',col=c,palette='twilight')
    ax.set_xticklabels(rotation=90)
    plt.show()

# %%
for vg in cat_df.columns:
    plot_df3(hr,vg)

# %%
hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# #### Check the relationship between the categorical variables by the stacked plot

# %%
plt.style.use('seaborn-paper') #For best visualization
gender=pd.crosstab(hr['Gender'],hr['Attrition'])  #Gender vs Attrition relation
gender.div(gender.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(10,6))
plt.legend(loc='upper right')
plt.show()

# %%
buss=pd.crosstab(hr['BusinessTravel'],hr['Attrition'])  #Bussiness travel vs Attrition 
buss.div(buss.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(10,6))
plt.legend(loc='upper right')
plt.show()

# %%
depart=pd.crosstab(hr['Department'],hr['Attrition'])  #Department vs Attrition
depart.div(depart.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(10,6))
plt.legend(loc='upper right')
plt.show()

# %%
dist=pd.crosstab(hr['DistanceFromHome'],hr['Attrition']) #The distance between the home to the office vs Attrition rate
dist.div(dist.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(15,6))
plt.legend(loc='upper right')
plt.show()

# %%
edu=pd.crosstab(hr['EducationField'],hr['Attrition'])  #The basic backgorund education field vs Attrition rate of the employees
edu.div(edu.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(10,6))
plt.legend(loc='upper right')
plt.show()

# %%
educ=pd.crosstab(hr['Education'],hr['Attrition'])  #The level of Education vs Chances of Attrition
educ.div(educ.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(10,6))
plt.legend(loc='upper right')
plt.show()

# %%
job=pd.crosstab(hr['JobRole'],hr['Attrition']) #The Rate of Attrition is high for Sales Representative and average for Reasearch Director
job.div(job.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(10,6))
plt.legend(loc='upper right')
plt.show()

# %%
jb=pd.crosstab(hr['NumCompaniesWorked'],hr['Attrition'])
jb.div(jb.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(10,6))
plt.legend(loc='upper right')
plt.show()

# %%
over=pd.crosstab(hr['OverTime'],hr['Attrition'])
over.div(over.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(10,6))
plt.legend(loc='upper right')
plt.show()

# %%
rel=pd.crosstab(hr['RelationshipSatisfaction'],hr['Attrition'])
rel.div(rel.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(10,6))
plt.legend(loc='upper right')
plt.show()

# %%
hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
#Encode the categorical values in to numerical values for proper understanding of the data during model building
cat_df=pd.get_dummies(cat_df,drop_first=True)
cat_df.head()
# Out:
#    Attrition_Yes  BusinessTravel_Travel_Frequently  \
# 0              1                                 0
# 1              0                                 1
# 2              1                                 0
# 3              0                                 1
# 4              0                                 0
#
#    BusinessTravel_Travel_Rarely  Department_Research & Development  \
# 0                             1                                  0
# 1                             0                                  1
# 2                             1                                  1
# 3                             0                                  1
# 4                             1                                  1
#
#    Department_Sales  EducationField_Life Sciences  EducationField_Marketing  \
# 0                 1                             1                         0
# 1                 0                             1                         0
# ...

# %%
#Conacte the dummies data in to main dataframe
hr=pd.concat([hr,cat_df],axis=1)

# %%
hr.drop(columns=cat_data,inplace=True)

# %%
hr.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# ...

# %% [markdown]
# After Endong the categorical data in to Numerical variables The dataset is look like these

# %%
#Rename the target variable
hr.rename(columns={"Attrition_Yes":'Attrition'},inplace=True)

# %%
#split the data in to 'x' and 'y'
x=hr.drop(columns='Attrition')
y=hr['Attrition']

# %%
y.value_counts() #Check the data is balanced or not
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %% [markdown]
# The target or independent variable is completely imbalanced we need to handle those conditions by using uppersampling or oversamplig

# %%
#Feature selection by xgboost
import xgboost
from xgboost import plot_importance
xgb=xgboost.XGBClassifier()
xgb.fit(x,y)


features=xgb.feature_importances_
columns=x.columns
for i,j in enumerate(features):
    print(columns[i],'--->',j)
    
plt.figure(figsize=(13,6))
plt.title('Feature importance by xgboost')
plt.bar([x for x in range(len(features))],features)
plt.show()
# Out:
# Age ---> 0.02470444
# DailyRate ---> 0.020823725
# DistanceFromHome ---> 0.022147998
# Education ---> 0.012847314
# EmployeeCount ---> 0.0
# EmployeeNumber ---> 0.019380813
# EnvironmentSatisfaction ---> 0.026703192
# HourlyRate ---> 0.01794573
# JobInvolvement ---> 0.025932107
# JobLevel ---> 0.039745044
# JobSatisfaction ---> 0.028089114
# MonthlyIncome ---> 0.034614425
# MonthlyRate ---> 0.016728703
# NumCompaniesWorked ---> 0.025792327
# PercentSalaryHike ---> 0.021607962
# PerformanceRating ---> 0.0
# RelationshipSatisfaction ---> 0.020781944
# StandardHours ---> 0.0
# StockOptionLevel ---> 0.042272896
# TotalWorkingYears ---> 0.028422749
# TrainingTimesLastYear ---> 0.019696917
# WorkLifeBalance ---> 0.025629828
# YearsAtCompany ---> 0.02933994
# YearsInCurrentRole ---> 0.018197339
# YearsSinceLastPromotion ---> 0.023380203
# YearsWithCurrManager ---> 0.020534951
# BusinessTravel_Travel_Frequently ---> 0.028078543
# BusinessTravel_Travel_Rarely ---> 0.026870783
# ...

# %%
#Feature importance by chi2
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest
select=SelectKBest(score_func=chi2,k=12)
select.fit(x,y)
# Out:
# SelectKBest(k=12, score_func=<function chi2 at 0x0000023C49836280>)

# %%
best_fea=pd.DataFrame(select.scores_,columns=['Value'],index=x.columns)
best_fea.nlargest(10,'Value').plot.bar()

# %%
#Lets remove some unwanted features form the data
x=x.drop(columns=['EmployeeCount','EmployeeNumber','PercentSalaryHike','StandardHours','TrainingTimesLastYear','WorkLifeBalance',
                'YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager'],axis=1)

# %%
#Model building
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
#feature transformation
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
print('x_train: {0}'.format(x_train.shape))
print('y_train: {0}'.format(y_train.shape))
print('x_test {0}'.format(x_test.shape))
print('y_test: {0}'.format(y_test.shape))
# Out:
# x_train: (1176, 37)
# y_train: (1176,)
# x_test (294, 37)
# y_test: (294,)

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
grid={'C':[0.01,0.02,0.05,0.07,0.1,0.5,0.7,0.1],'penalty':['l1', 'l2']}
log.fit(x_train,y_train)

log_pred=log.predict(x_test)

# %%
cv=KFold(n_splits=10,random_state=0,shuffle=False)
# Out:
# C:\Users\Praneeth\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV,cross_val_score,KFold
log_g=GridSearchCV(log,param_grid=grid,cv=cv,n_jobs=-1,verbose=2,scoring='f1_micro')
log_g.fit(x_train,y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed:    1.0s finished
# GridSearchCV(cv=KFold(n_splits=10, random_state=0, shuffle=False),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.01, 0.02, 0.05, 0.07, 0.1, 0.5, 0.7, 0.1],
#                          'penalty': ['l1', 'l2']},
#              scoring='f1_micro', verbose=2)

# %%
log_best=log_g.best_estimator_
log_best_pred=log_best.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print('Accuracy_score: {0}'.format(accuracy_score(y_test,log_best_pred)))
print(classification_report(y_test,log_best_pred))
print(confusion_matrix(y_test,log_best_pred))
# Out:
# Accuracy_score: 0.891156462585034
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       245
#            1       0.90      0.39      0.54        49
#
#     accuracy                           0.89       294
#    macro avg       0.90      0.69      0.74       294
# weighted avg       0.89      0.89      0.87       294
#
# [[243   2]
#  [ 30  19]]

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
grid={'n_estimators':list(np.arange(100,1000,100)),'max_depth':[7,9,10,13,15],'max_features' : ["auto", "sqrt", "log2"]}
rf.fit(x_train,y_train)
rf_pred=rf.predict(x_test)

# %%
print('Accuracy_score: {0}'.format(accuracy_score(y_test,best_grid_ref_fit)))
print(classification_report(y_test,best_grid_ref_fit))
print(confusion_matrix(y_test,best_grid_ref_fit))
# Out:
# Accuracy_score: 0.8503401360544217
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92       245
#            1       0.86      0.12      0.21        49
#
#     accuracy                           0.85       294
#    macro avg       0.85      0.56      0.57       294
# weighted avg       0.85      0.85      0.80       294
#
# [[244   1]
#  [ 43   6]]

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
svc_pred=svc.predict(x_test)

# %%
print('Accuracy_score: {0}'.format(accuracy_score(y_test,svc_pred)))
print(classification_report(y_test,svc_pred))
print(confusion_matrix(y_test,svc_pred))
# Out:
# Accuracy_score: 0.8639455782312925
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       245
#            1       0.85      0.22      0.35        49
#
#     accuracy                           0.86       294
#    macro avg       0.86      0.61      0.64       294
# weighted avg       0.86      0.86      0.83       294
#
# [[243   2]
#  [ 38  11]]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=6)
knn.fit(x_train,y_train)
knn_pred=knn.predict(x_test)

# %%
print('Accuracy_score: {0}'.format(accuracy_score(y_test,knn_pred)))
print(classification_report(y_test,knn_pred))
print(confusion_matrix(y_test,knn_pred))
# Out:
# Accuracy_score: 0.8435374149659864
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       245
#            1       0.71      0.10      0.18        49
#
#     accuracy                           0.84       294
#    macro avg       0.78      0.55      0.55       294
# weighted avg       0.82      0.84      0.79       294
#
# [[243   2]
#  [ 44   5]]

# %%
import xgboost
xgb=xgboost.XGBClassifier()
xgb.fit(x_train,y_train)

xgb_pred=xgb.predict(x_test)

# %%
print('Accuracy_score: {0}'.format(accuracy_score(y_test,xgb_pred)))
print(classification_report(y_test,xgb_pred))
print(confusion_matrix(y_test,xgb_pred))
# Out:
# Accuracy_score: 0.8503401360544217
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       245
#            1       0.61      0.29      0.39        49
#
#     accuracy                           0.85       294
#    macro avg       0.74      0.62      0.65       294
# weighted avg       0.83      0.85      0.83       294
#
# [[236   9]
#  [ 35  14]]

# %%
import lightgbm
light=lightgbm.LGBMClassifier()
light.fit(x_train,y_train)

light_pred=light.predict(x_test)

# %%
print('Accuracy_score: {0}'.format(accuracy_score(y_test,light_pred)))
print(classification_report(y_test,light_pred))
print(confusion_matrix(y_test,light_pred))
# Out:
# Accuracy_score: 0.8673469387755102
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.92       245
#            1       0.75      0.31      0.43        49
#
#     accuracy                           0.87       294
#    macro avg       0.81      0.64      0.68       294
# weighted avg       0.85      0.87      0.84       294
#
# [[240   5]
#  [ 34  15]]
